# %% [markdown]
# ## Dependencies
#
# Folgende Python-Packages werden für die Ausführung der in diesem Projekt enthaltenen Notebooks benötigt:

# %%
# %pip install -U \
  "transformers==4.51.3" \
  "tokenizers==0.21.4" \
  "sentence-transformers==5.3.0" \
  "datasets==2.21.0" \
  "huggingface_hub==0.36.2" \
  "accelerate==1.13.0" \
  "adapter-transformers==4.0.0" \
  "langchain-core==1.2.12" \
  "langchain-openai==1.1.9" \
  "ipywidgets==8.1.8" \
  "tiktoken==0.12.0"
